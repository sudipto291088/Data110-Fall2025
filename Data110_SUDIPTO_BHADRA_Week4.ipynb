# %% [markdown]
# <a href="https://colab.research.google.com/github/sudipto291088/Data110-Fall2025/blob/main/Data110_SUDIPTO_BHADRA_Week4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Data for the table
data = {
    "Offences": [
        "Aggravated Assault",
        "Burglary",
        "Larceny",
        "Motor Vehicle theft",
        "Murder",
        "Rape (revised definition)",
        "Robbery"
    ],
    "Offenses per 100,000 People (2023)": [
        264.1,
        250.7,
        1347.2,
        318.7,
        5.7,
        38.0,
        66.5
    ],
    "Change in Offenses per 100,000 People (2022-2023)": [
        -3.3,
        -8.1,
        -4.9,
        +12.0,
        -12.0,
        -9.8,
        -0.8
    ]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Displaying table
print(df)
# Out:
#                     Offences  Offenses per 100,000 People (2023)  \
# 0         Aggravated Assault                               264.1
# 1                   Burglary                               250.7
# 2                    Larceny                              1347.2
# 3        Motor Vehicle theft                               318.7
# 4                     Murder                                 5.7
# 5  Rape (revised definition)                                38.0
# 6                    Robbery                                66.5
#
#    Change in Offenses per 100,000 People (2022-2023)
# 0                                               -3.3
# 1                                               -8.1
# 2                                               -4.9
# 3                                               12.0
# 4                                              -12.0
# 5                                               -9.8
# 6                                               -0.8

# %% [markdown]
# # Task 1: Basic Bar Chart for Crime Rates in 2023
#
# ---
#
#
# In this task, you will create a bar chart showing the offense rates per 100,000 people for each type of crime in 2023.
#
# **Instructions:**
#
# Create a bar chart for crime rates in 2023.
#
# Customize the bar colors and add gridlines.
#
# Label the axes and add a title.

# %%
# Creating the bar chart
plt.figure(figsize=(10,6))
bars = plt.bar(df["Offences"],
               df["Offenses per 100,000 People (2023)"],
               color=["blue", "orange", "red",
                      "green", "maroon", "purple", "brown"])

# Customizing chart
plt.xlabel("Type of Crime")
plt.ylabel("Offenses per 100,000 People (2023)")
plt.title("Crime Rates in 2023 per 100,000 People")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Rotating x-axis labels for readability
plt.xticks(rotation=70, ha="right")
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Aggravated Assault'),
#   Text(1, 0, 'Burglary'),
#   Text(2, 0, 'Larceny'),
#   Text(3, 0, 'Motor Vehicle theft'),
#   Text(4, 0, 'Murder'),
#   Text(5, 0, 'Rape (revised definition)'),
#   Text(6, 0, 'Robbery')])

# %% [markdown]
# # Task 2: Change in Crime Rates (2022 vs. 2023) with Unique Colors
#
# ---
#
#
# In this task, you will create a **horizontal bar chart** that visualizes the **percentage change** in offense rates from 2022 to 2023 for each crime type. Each bar should have a unique color for better distinction.
#
# **Instructions:**
#
#
#
# *   Create a horizontal bar chart showing the change in offense rates.
#
# *   Assign a unique color to each crime type.
# *   Label the axes and add a title.
#
#
#
#
#
# **Additional Instructions:**
#
#
#
# 1.   **Why does this bar graph make more sense than Task 1's bar graph?**
#
#
#
#
# *   Think about how absolute numbers (like total crime rates) might be misleading compared to percentage changes.
#
# *   Explain why seeing the change over time is more insightful than just seeing the total number of offenses for a single year.
#
#
#
#
#
# 2.  **Improve the clarity of your bar graph:**
#
#
#
# *   Create multiple versions of the bar chart for Task 2, each time making the chart more clear and readable.
# *   Experiment with different color schemes, labels, and gridlines.
#
# *   In each iteration, focus on improving the ease with which someone can quickly understand the trends in crime rates.

# %%
# Creating the bar chart
plt.figure(figsize=(10,6))
bar2 = plt.bar(df["Offences"],
               df["Change in Offenses per 100,000 People (2022-2023)"],
               color=["olive", "olivedrab", "lawngreen",
                      "red", "lime", "seagreen", "springgreen"])

# Customizing chart
plt.xlabel("Type of Crime")
plt.ylabel("Change in Offenses per 100,000 People (2022-2023) ")
plt.title("Changes in Offenses per 100,000 People in the period between 22-23")
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Rotating x-axis labels for readability
plt.xticks(rotation=70, ha="right")
# Out:
# ([0, 1, 2, 3, 4, 5, 6],
#  [Text(0, 0, 'Aggravated Assault'),
#   Text(1, 0, 'Burglary'),
#   Text(2, 0, 'Larceny'),
#   Text(3, 0, 'Motor Vehicle theft'),
#   Text(4, 0, 'Murder'),
#   Text(5, 0, 'Rape (revised definition)'),
#   Text(6, 0, 'Robbery')])

# %% [markdown]
# # Why does this bar graph make more sense than Task 1's bar graph?
#
# ---
#
# Although the first chart is still useful, however one might question the illogical mapping of 'Larceny' along with other crimes given the fact that Larceny has a much higher rate than any others.
#
# The **Percentage changes** are much better in this context because they depict how the crime rates are evolving. Not simply mapping them but also a clear study if the CR are increasing or decreasing.
#
# Seeing the change over time is good for the general citizens plus the policymakers. It is reassuring for them if the trend is towards a positive side indicating that the society is heading towards being safer for everyone.

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'petroff10', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
## Improving the clarity of the Bar graph



# Sort by change for better trend visibility
df = df.sort_values('Change in Offenses per 100,000 People (2022-2023)')

# Set style
plt.style.use('seaborn-v0_8')
plt.figure(figsize=(10, 6))

# Use viridis color palette
colors = sns.color_palette("viridis", len(df))

# Create horizontal bar chart
bars = plt.barh(df['Offences'], df['Change in Offenses per 100,000 People (2022-2023)'], color=colors)

# Add labels and title
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=12)
plt.ylabel('Offence Type', fontsize=12)
plt.title('Percentage Change in Crime Rates (2022 vs. 2023)', fontsize=14)

# Add gridlines
plt.grid(True, axis='x', linestyle='--', alpha=0.7)

# Add value labels
for bar in bars:
    width = bar.get_width()
    label_x = width if width >= 0 else width - 0.5
    plt.text(label_x, bar.get_y() + bar.get_height()/2, f'{width:.1f}',
             va='center', ha='right' if width >= 0 else 'left', fontsize=10)

plt.tight_layout()
plt.show()

# %%
# Sort by change
df = df.sort_values('Change in Offenses per 100,000 People (2022-2023)')

# Set style
plt.style.use('seaborn-v0_8-colorblind')
plt.figure(figsize=(12, 7))

# Use Set2 palette for high contrast
colors = sns.color_palette("Set2", len(df))

# Create horizontal bar chart
bars = plt.barh(df['Offences'], df['Change in Offenses per 100,000 People (2022-2023)'],
                color=colors, height=0.1)

# Add zero line
plt.axvline(x=0, color='black', linestyle='-', linewidth=1)

# Add labels and title
plt.xlabel('Change in Offenses per 100,000 People (2022-2023)', fontsize=12)
plt.ylabel('Offence Type', fontsize=12)
plt.title('Percentage Change in Crime Rates (2022 vs. 2023)', fontsize=14)

# Add gridlines
plt.grid(True, axis='x', linestyle='--', alpha=0.7)

# Add value labels with slight offset
for bar in bars:
    width = bar.get_width()
    label_x = width + 0.5 if width >= 0 else width - 0.5
    plt.text(label_x, bar.get_y() + bar.get_height()/2, f'{width:.1f}',
             va='center', ha='left' if width >= 0 else 'right', fontsize=10)

plt.tight_layout()
plt.show()
